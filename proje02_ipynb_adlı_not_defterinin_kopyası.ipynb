# %% [markdown]
# <a href="https://colab.research.google.com/github/ilaydaatilgan/hu-bby162-2022/blob/main/proje02_ipynb_adl%C4%B1_not_defterinin_kopyas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import choice
 
kelimeler=[" ", " ", " ", " "]


def Basitseviye():
   print("Basit seviye seçildi")
def OrtaSeviye():
   print("Orta seviye seçildi")
def Ileriseviye():
   print("İleri seviye seçildi")
   

def menu():
    fonksiyonListesi=[Basitseviye, OrtaSeviye, Ileriseviye]
    while True:
        print("1-Basit seviye")
        print("2-Orta seviye")
        print("3-İleri seviye")
        
        seciminiz=int(input("Lütfen oynamak istediğiniz seviyeyi seçiniz.(0-3): "))
        if seciminiz==1:
           print("Basit seviye ile başlayacaksınız.")
           
           adamCan = 10

        kelimeler = ["kuş", "tazı", "öküz", "inek"]
        secilenKelime = choice(kelimeler)
        dizilenKelime = [] 
        for diz in secilenKelime:
            dizilenKelime.append("_")
        print(dizilenKelime)

    while adamCan > 0:
           girilenHarf = input("Bir harf giriniz: ")
           canKontrol = girilenHarf in secilenKelime
           if canKontrol == False:
              adamCan-=1
           i = 0
           for kontrol in secilenKelime:
              if secilenKelime[i] == girilenHarf:
                  dizilenKelime[i] = girilenHarf
              i+=1
           print(dizilenKelime)
           print("Kalan can: "+ str(adamCan))
           if adamCan ==0:
             print("Üzgünüz, basit seviyeyi geçemediniz.")
           
           
           
           
           if seciminiz==2:
                print("Orta seviye ile başlayacaksınız.")
                adamCan = 5

           kelimeler = ["yağmur", "şimşek", "güneş", "fırtına"]
           secilenKelime = choice(kelimeler)
           print(secilenKelime)
           dizilenKelime = []
           for diz in secilenKelime:
             dizilenKelime.append("_")
           print(dizilenKelime)

    while adamCan > 0:
       girilenHarf = input("Bir harf giriniz: ")
       canKontrol = girilenHarf in secilenKelime
       if canKontrol == False:
         adamCan-=1
       i = 0
       for kontrol in secilenKelime:
         if secilenKelime[i] == girilenHarf:
           dizilenKelime[i] = girilenHarf
         i+=1
         print(dizilenKelime)
         print("Kalan can: "+ str(adamCan))
         if adamCan ==0:
              print("Üzgünüz, orta seviyeyi geçemediniz.")
        
    if seciminiz==3:
        print("İleri seviyeden başlayacaksınız")

        adamCan = 3

    kelimeler = ["istanbul", "şanlıurfa", "balıkesir", "nevşehir"]
    secilenKelime = choice(kelimeler)
    dizilenKelime = []
    for diz in secilenKelime:
        dizilenKelime.append("_")
    print(dizilenKelime)

    while adamCan > 0:
       girilenHarf = input("Bir harf giriniz: ")
       canKontrol = girilenHarf in secilenKelime
       if canKontrol == False:
        adamCan-=1
       i = 0
       for kontrol in secilenKelime:
         if secilenKelime[i] == girilenHarf:
           dizilenKelime[i] = girilenHarf
         i+=1
         print(dizilenKelime)
         print("Kalan can: "+ str(adamCan))
         if adamCan ==0:
           print("Üzgünüz, ileri seviyeyi geçemediniz.")
           break
           print("Maalesef, Kaybettiniz!")
            
          

       

menu()
# Out:
# 1-Basit seviye
# 2-Orta seviye
# 3-İleri seviye
# Lütfen oynamak istediğiniz seviyeyi seçiniz.(0-3): 2
# ['_', '_', '_']
# 1-Basit seviye
# 2-Orta seviye
# 3-İleri seviye
